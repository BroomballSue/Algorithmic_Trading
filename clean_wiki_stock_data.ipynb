# %%
import pandas as pd
import h5py

# %%
df=pd.read_csv("WIKI_PRICES.csv")

df.info(verbose=True)

df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15389314 entries, 0 to 15389313
# Data columns (total 14 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   ticker       object
#  1   date         object
#  2   open         float64
#  3   high         float64
#  4   low          float64
#  5   close        float64
#  6   volume       float64
#  7   ex-dividend  float64
#  8   split_ratio  float64
#  9   adj_open     float64
#  10  adj_high     float64
#  11  adj_low      float64
#  12  adj_close    float64
#  13  adj_volume   float64
# dtypes: float64(12), object(2)
# memory usage: 1.6+ GB
#          ticker        date   open   high      low  close      volume  \
# 0             A  1999-11-18  45.50  50.00  40.0000  44.00  44739900.0
# 1             A  1999-11-19  42.94  43.00  39.8100  40.38  10897100.0
# 2             A  1999-11-22  41.31  44.00  40.0600  44.00   4705200.0
# 3             A  1999-11-23  42.50  43.63  40.2500  40.25   4274400.0
# ...

# %%
df["date"] = pd.to_datetime(df["date"])

df = df.set_index(['ticker', 'date']) # create a multiindex

df=df.drop(columns=['open', 'high'],axis=1)
df.drop(df.columns[[0, 1, 2, 3, 4]], axis = 1, inplace = True) # different ways of dropping columns

df=df[df.index.get_level_values(1)>'2000-01-01'] # because the date is part of a multiindex

df.columns = df.columns.str.replace('adj_', '') #renaming the remaining columns


df.info(verbose=True) # to check everything worked
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 11343920 entries, ('A', Timestamp('2000-01-03 00:00:00')) to ('ZUMZ', Timestamp('2018-03-27 00:00:00'))
# Data columns (total 5 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   open    float64
#  1   high    float64
#  2   low     float64
#  3   close   float64
#  4   volume  float64
# dtypes: float64(5)
# memory usage: 476.8+ MB
#                         open       high        low      close     volume
# ticker date
# A      2000-01-03  53.726454  53.856080  45.969377  49.121329  3343600.0
#        2000-01-04  46.481058  46.992738  44.175084  45.369006  3408500.0
#        2000-01-05  45.198445  45.239380  41.828176  41.998737  4119200.0
#        2000-01-06  42.046493  42.298923  39.658651  40.934441  1812900.0
#        2000-01-07  40.293135  44.986951  40.252200  44.345645  2016900.0
# ...                      ...        ...        ...        ...        ...
# ...

# %%
df.to_hdf('stock_data.h5', key='df', mode='w')  # writing the file to the disk in a hdf5 format
